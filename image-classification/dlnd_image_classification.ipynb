# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    x = (x-x.min()) / (x.max()-x.min())
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    I = np.eye(10)
    x = I[x]
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=(None, *image_shape), name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=(None, n_classes), name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=None, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    tensor_shape = x_tensor.get_shape().as_list()
    image_size, image_layer = tensor_shape[1], tensor_shape[3] 
    pixel_num = image_size * image_size * image_layer
    print('tensor_shape: ', tensor_shape)
    
    conv_size = (conv_ksize[0],conv_ksize[1],tensor_shape[3],conv_num_outputs)
    W = tf.Variable( tf.truncated_normal(conv_size,0,( 1/np.sqrt(pixel_num) )) )
    b = tf.Variable( tf.zeros(conv_num_outputs) )
    
    conv2d_bias = tf.nn.conv2d(x_tensor, W, strides=(1,*conv_strides,1), padding='SAME') + b
    relu = tf.nn.relu(conv2d_bias)
    conv2d_bias_relu_maxpool = tf.nn.max_pool( relu, ksize=(1,*pool_ksize,1), strides=(1,*pool_strides,1),padding='SAME')
    
    return conv2d_bias_relu_maxpool 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# tensor_shape:  [None, 32, 32, 5]
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    return tf.contrib.layers.flatten(x_tensor)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    batch_size, input_size = x_tensor.get_shape().as_list()
    W = tf.Variable( tf.truncated_normal([input_size, num_outputs], 0, 0.01) )
    b = tf.Variable( tf.zeros(num_outputs) ) 
    
    return tf.nn.relu( tf.matmul(x_tensor, W) + b )


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    batch_size, input_size = x_tensor.get_shape().as_list()
    W = tf.Variable( tf.truncated_normal([input_size, num_outputs], 0, 0.01) )
    b = tf.Variable( tf.zeros(num_outputs) ) 
    
    return ( tf.matmul(x_tensor, W) + b )


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    conv_num_outputs = 64
    conv_ksize = (5,5)
    conv_strides = (1,1)
    pool_ksize = (3,3)
    pool_strides = (1,1)
    num_outputs = 10
    num_outputs_fully = 64
    
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    conv = flatten(conv)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fully = fully_conn(conv, num_outputs)
    fully = tf.nn.dropout(fully, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    output_layer = output(fully, num_outputs)
    
    
    # TODO: return output
    return output_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# tensor_shape:  [None, 32, 32, 3]
# tensor_shape:  [None, 32, 32, 3]
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x:feature_batch, y:label_batch, keep_prob:keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run( cost, feed_dict={ x: feature_batch, y: label_batch, keep_prob: 1.0} )
    valid_accuracy = session.run( accuracy, feed_dict={ x: valid_features, y: valid_labels, keep_prob: 1.0} )
    print('Loss = {:>.4f}, Validation Accuracy = {:.6f}'.format(loss, valid_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 1024
keep_probability = 0.8

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss = 2.2478, Validation Accuracy = 0.175200
# Epoch  2, CIFAR-10 Batch 1:  Loss = 2.1515, Validation Accuracy = 0.203000
# Epoch  3, CIFAR-10 Batch 1:  Loss = 2.0694, Validation Accuracy = 0.251800
# Epoch  4, CIFAR-10 Batch 1:  Loss = 2.0316, Validation Accuracy = 0.276000
# Epoch  5, CIFAR-10 Batch 1:  Loss = 1.9468, Validation Accuracy = 0.303600
# Epoch  6, CIFAR-10 Batch 1:  Loss = 1.8691, Validation Accuracy = 0.321600
# Epoch  7, CIFAR-10 Batch 1:  Loss = 1.8218, Validation Accuracy = 0.348800
# Epoch  8, CIFAR-10 Batch 1:  Loss = 1.7697, Validation Accuracy = 0.354600
# Epoch  9, CIFAR-10 Batch 1:  Loss = 1.7418, Validation Accuracy = 0.363200
# Epoch 10, CIFAR-10 Batch 1:  Loss = 1.7011, Validation Accuracy = 0.384000
# Epoch 11, CIFAR-10 Batch 1:  Loss = 1.6761, Validation Accuracy = 0.395000
# Epoch 12, CIFAR-10 Batch 1:  Loss = 1.6506, Validation Accuracy = 0.404600
# Epoch 13, CIFAR-10 Batch 1:  Loss = 1.6219, Validation Accuracy = 0.413800
# Epoch 14, CIFAR-10 Batch 1:  Loss = 1.6171, Validation Accuracy = 0.410600
# Epoch 15, CIFAR-10 Batch 1:  Loss = 1.5879, Validation Accuracy = 0.421200
# Epoch 16, CIFAR-10 Batch 1:  Loss = 1.5724, Validation Accuracy = 0.419800
# Epoch 17, CIFAR-10 Batch 1:  Loss = 1.5396, Validation Accuracy = 0.433400
# Epoch 18, CIFAR-10 Batch 1:  Loss = 1.5398, Validation Accuracy = 0.430600
# Epoch 19, CIFAR-10 Batch 1:  Loss = 1.5086, Validation Accuracy = 0.439800
# Epoch 20, CIFAR-10 Batch 1:  Loss = 1.4898, Validation Accuracy = 0.444000
# Epoch 21, CIFAR-10 Batch 1:  Loss = 1.4784, Validation Accuracy = 0.444400
# Epoch 22, CIFAR-10 Batch 1:  Loss = 1.4587, Validation Accuracy = 0.457200
# Epoch 23, CIFAR-10 Batch 1:  Loss = 1.4865, Validation Accuracy = 0.443400
# Epoch 24, CIFAR-10 Batch 1:  Loss = 1.4303, Validation Accuracy = 0.461600
# Epoch 25, CIFAR-10 Batch 1:  Loss = 1.4498, Validation Accuracy = 0.454400
# Epoch 26, CIFAR-10 Batch 1:  Loss = 1.4150, Validation Accuracy = 0.459600
# Epoch 27, CIFAR-10 Batch 1:  Loss = 1.4073, Validation Accuracy = 0.458200
# Epoch 28, CIFAR-10 Batch 1:  Loss = 1.3864, Validation Accuracy = 0.471000
# Epoch 29, CIFAR-10 Batch 1:  Loss = 1.3888, Validation Accuracy = 0.468400
# Epoch 30, CIFAR-10 Batch 1:  Loss = 1.3704, Validation Accuracy = 0.471800
# Epoch 31, CIFAR-10 Batch 1:  Loss = 1.3635, Validation Accuracy = 0.468400
# Epoch 32, CIFAR-10 Batch 1:  Loss = 1.3759, Validation Accuracy = 0.466600
# Epoch 33, CIFAR-10 Batch 1:  Loss = 1.3662, Validation Accuracy = 0.471600
# Epoch 34, CIFAR-10 Batch 1:  Loss = 1.3289, Validation Accuracy = 0.479600
# Epoch 35, CIFAR-10 Batch 1:  Loss = 1.3034, Validation Accuracy = 0.494000
# Epoch 36, CIFAR-10 Batch 1:  Loss = 1.3360, Validation Accuracy = 0.478400
# Epoch 37, CIFAR-10 Batch 1:  Loss = 1.2948, Validation Accuracy = 0.493400
# Epoch 38, CIFAR-10 Batch 1:  Loss = 1.2712, Validation Accuracy = 0.496600
# Epoch 39, CIFAR-10 Batch 1:  Loss = 1.2763, Validation Accuracy = 0.492200
# Epoch 40, CIFAR-10 Batch 1:  Loss = 1.2663, Validation Accuracy = 0.493200
# Epoch 41, CIFAR-10 Batch 1:  Loss = 1.2817, Validation Accuracy = 0.486800
# Epoch 42, CIFAR-10 Batch 1:  Loss = 1.2579, Validation Accuracy = 0.495200
# Epoch 43, CIFAR-10 Batch 1:  Loss = 1.2317, Validation Accuracy = 0.500200
# Epoch 44, CIFAR-10 Batch 1:  Loss = 1.2182, Validation Accuracy = 0.502000
# Epoch 45, CIFAR-10 Batch 1:  Loss = 1.2304, Validation Accuracy = 0.503400
# Epoch 46, CIFAR-10 Batch 1:  Loss = 1.2169, Validation Accuracy = 0.506400
# Epoch 47, CIFAR-10 Batch 1:  Loss = 1.2130, Validation Accuracy = 0.500600
# Epoch 48, CIFAR-10 Batch 1:  Loss = 1.2179, Validation Accuracy = 0.500200
# Epoch 49, CIFAR-10 Batch 1:  Loss = 1.1796, Validation Accuracy = 0.508600
# Epoch 50, CIFAR-10 Batch 1:  Loss = 1.1732, Validation Accuracy = 0.504400
# Epoch 51, CIFAR-10 Batch 1:  Loss = 1.1784, Validation Accuracy = 0.501000
# Epoch 52, CIFAR-10 Batch 1:  Loss = 1.1812, Validation Accuracy = 0.506600
# Epoch 53, CIFAR-10 Batch 1:  Loss = 1.1646, Validation Accuracy = 0.509000
# Epoch 54, CIFAR-10 Batch 1:  Loss = 1.1451, Validation Accuracy = 0.512800
# Epoch 55, CIFAR-10 Batch 1:  Loss = 1.1510, Validation Accuracy = 0.516800
# Epoch 56, CIFAR-10 Batch 1:  Loss = 1.1429, Validation Accuracy = 0.519200
# Epoch 57, CIFAR-10 Batch 1:  Loss = 1.1384, Validation Accuracy = 0.515200
# Epoch 58, CIFAR-10 Batch 1:  Loss = 1.1174, Validation Accuracy = 0.515000
# Epoch 59, CIFAR-10 Batch 1:  Loss = 1.1024, Validation Accuracy = 0.520400
# Epoch 60, CIFAR-10 Batch 1:  Loss = 1.1048, Validation Accuracy = 0.521000
# Epoch 61, CIFAR-10 Batch 1:  Loss = 1.1060, Validation Accuracy = 0.520600
# Epoch 62, CIFAR-10 Batch 1:  Loss = 1.1112, Validation Accuracy = 0.519000
# Epoch 63, CIFAR-10 Batch 1:  Loss = 1.0737, Validation Accuracy = 0.522200
# Epoch 64, CIFAR-10 Batch 1:  Loss = 1.0757, Validation Accuracy = 0.520000
# Epoch 65, CIFAR-10 Batch 1:  Loss = 1.0732, Validation Accuracy = 0.519800
# Epoch 66, CIFAR-10 Batch 1:  Loss = 1.0652, Validation Accuracy = 0.525200
# Epoch 67, CIFAR-10 Batch 1:  Loss = 1.0490, Validation Accuracy = 0.526800
# Epoch 68, CIFAR-10 Batch 1:  Loss = 1.0706, Validation Accuracy = 0.520800
# Epoch 69, CIFAR-10 Batch 1:  Loss = 1.0397, Validation Accuracy = 0.526600
# Epoch 70, CIFAR-10 Batch 1:  Loss = 1.0477, Validation Accuracy = 0.525400
# Epoch 71, CIFAR-10 Batch 1:  Loss = 1.0174, Validation Accuracy = 0.530800
# Epoch 72, CIFAR-10 Batch 1:  Loss = 1.0070, Validation Accuracy = 0.533800
# Epoch 73, CIFAR-10 Batch 1:  Loss = 1.0005, Validation Accuracy = 0.533000
# Epoch 74, CIFAR-10 Batch 1:  Loss = 1.0098, Validation Accuracy = 0.525200
# Epoch 75, CIFAR-10 Batch 1:  Loss = 1.0147, Validation Accuracy = 0.522800
# Epoch 76, CIFAR-10 Batch 1:  Loss = 0.9994, Validation Accuracy = 0.530200
# Epoch 77, CIFAR-10 Batch 1:  Loss = 0.9694, Validation Accuracy = 0.538800
# Epoch 78, CIFAR-10 Batch 1:  Loss = 0.9534, Validation Accuracy = 0.539000
# Epoch 79, CIFAR-10 Batch 1:  Loss = 0.9419, Validation Accuracy = 0.539600
# Epoch 80, CIFAR-10 Batch 1:  Loss = 0.9241, Validation Accuracy = 0.539400
# Epoch 81, CIFAR-10 Batch 1:  Loss = 0.9177, Validation Accuracy = 0.538600
# Epoch 82, CIFAR-10 Batch 1:  Loss = 0.9077, Validation Accuracy = 0.542800
# Epoch 83, CIFAR-10 Batch 1:  Loss = 0.9372, Validation Accuracy = 0.532400
# Epoch 84, CIFAR-10 Batch 1:  Loss = 0.9220, Validation Accuracy = 0.539400
# Epoch 85, CIFAR-10 Batch 1:  Loss = 0.9010, Validation Accuracy = 0.539000
# Epoch 86, CIFAR-10 Batch 1:  Loss = 0.9151, Validation Accuracy = 0.542200
# Epoch 87, CIFAR-10 Batch 1:  Loss = 0.8882, Validation Accuracy = 0.537800
# Epoch 88, CIFAR-10 Batch 1:  Loss = 0.9076, Validation Accuracy = 0.529400
# Epoch 89, CIFAR-10 Batch 1:  Loss = 0.9016, Validation Accuracy = 0.532800
# Epoch 90, CIFAR-10 Batch 1:  Loss = 0.8800, Validation Accuracy = 0.541800
# Epoch 91, CIFAR-10 Batch 1:  Loss = 0.8723, Validation Accuracy = 0.542800
# Epoch 92, CIFAR-10 Batch 1:  Loss = 0.8623, Validation Accuracy = 0.543400
# Epoch 93, CIFAR-10 Batch 1:  Loss = 0.8559, Validation Accuracy = 0.543800
# Epoch 94, CIFAR-10 Batch 1:  Loss = 0.8476, Validation Accuracy = 0.546000
# Epoch 95, CIFAR-10 Batch 1:  Loss = 0.8580, Validation Accuracy = 0.546200
# Epoch 96, CIFAR-10 Batch 1:  Loss = 0.8571, Validation Accuracy = 0.536800
# Epoch 97, CIFAR-10 Batch 1:  Loss = 0.8348, Validation Accuracy = 0.542600
# Epoch 98, CIFAR-10 Batch 1:  Loss = 0.8336, Validation Accuracy = 0.550400
# Epoch 99, CIFAR-10 Batch 1:  Loss = 0.8289, Validation Accuracy = 0.545000
# Epoch 100, CIFAR-10 Batch 1:  Loss = 0.8245, Validation Accuracy = 0.540000

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss = 2.2372, Validation Accuracy = 0.128000
# Epoch  1, CIFAR-10 Batch 2:  Loss = 2.1278, Validation Accuracy = 0.178600
# Epoch  1, CIFAR-10 Batch 3:  Loss = 2.0735, Validation Accuracy = 0.217000
# Epoch  1, CIFAR-10 Batch 4:  Loss = 1.9870, Validation Accuracy = 0.246600
# Epoch  1, CIFAR-10 Batch 5:  Loss = 1.9482, Validation Accuracy = 0.260600
# Epoch  2, CIFAR-10 Batch 1:  Loss = 1.8994, Validation Accuracy = 0.294400
# Epoch  2, CIFAR-10 Batch 2:  Loss = 1.8528, Validation Accuracy = 0.305600
# Epoch  2, CIFAR-10 Batch 3:  Loss = 1.7848, Validation Accuracy = 0.309400
# Epoch  2, CIFAR-10 Batch 4:  Loss = 1.7717, Validation Accuracy = 0.330600
# Epoch  2, CIFAR-10 Batch 5:  Loss = 1.8058, Validation Accuracy = 0.328200
# Epoch  3, CIFAR-10 Batch 1:  Loss = 1.7678, Validation Accuracy = 0.353800
# Epoch  3, CIFAR-10 Batch 2:  Loss = 1.7432, Validation Accuracy = 0.351000
# Epoch  3, CIFAR-10 Batch 3:  Loss = 1.6766, Validation Accuracy = 0.377000
# Epoch  3, CIFAR-10 Batch 4:  Loss = 1.6706, Validation Accuracy = 0.378800
# Epoch  3, CIFAR-10 Batch 5:  Loss = 1.7012, Validation Accuracy = 0.375000
# Epoch  4, CIFAR-10 Batch 1:  Loss = 1.6679, Validation Accuracy = 0.386000
# Epoch  4, CIFAR-10 Batch 2:  Loss = 1.6767, Validation Accuracy = 0.384200
# Epoch  4, CIFAR-10 Batch 3:  Loss = 1.5996, Validation Accuracy = 0.400600
# Epoch  4, CIFAR-10 Batch 4:  Loss = 1.5898, Validation Accuracy = 0.394400
# Epoch  4, CIFAR-10 Batch 5:  Loss = 1.6250, Validation Accuracy = 0.408800
# Epoch  5, CIFAR-10 Batch 1:  Loss = 1.6010, Validation Accuracy = 0.412800
# Epoch  5, CIFAR-10 Batch 2:  Loss = 1.6042, Validation Accuracy = 0.415600
# Epoch  5, CIFAR-10 Batch 3:  Loss = 1.5329, Validation Accuracy = 0.422000
# Epoch  5, CIFAR-10 Batch 4:  Loss = 1.5353, Validation Accuracy = 0.416600
# Epoch  5, CIFAR-10 Batch 5:  Loss = 1.5657, Validation Accuracy = 0.429600
# Epoch  6, CIFAR-10 Batch 1:  Loss = 1.5562, Validation Accuracy = 0.428000
# Epoch  6, CIFAR-10 Batch 2:  Loss = 1.5671, Validation Accuracy = 0.429600
# Epoch  6, CIFAR-10 Batch 3:  Loss = 1.4776, Validation Accuracy = 0.440400
# Epoch  6, CIFAR-10 Batch 4:  Loss = 1.5049, Validation Accuracy = 0.428800
# Epoch  6, CIFAR-10 Batch 5:  Loss = 1.5095, Validation Accuracy = 0.443800
# Epoch  7, CIFAR-10 Batch 1:  Loss = 1.5057, Validation Accuracy = 0.447400
# Epoch  7, CIFAR-10 Batch 2:  Loss = 1.5284, Validation Accuracy = 0.443800
# Epoch  7, CIFAR-10 Batch 3:  Loss = 1.4446, Validation Accuracy = 0.454400
# Epoch  7, CIFAR-10 Batch 4:  Loss = 1.4715, Validation Accuracy = 0.445600
# Epoch  7, CIFAR-10 Batch 5:  Loss = 1.4852, Validation Accuracy = 0.450200
# Epoch  8, CIFAR-10 Batch 1:  Loss = 1.4875, Validation Accuracy = 0.457000
# Epoch  8, CIFAR-10 Batch 2:  Loss = 1.5178, Validation Accuracy = 0.445400
# Epoch  8, CIFAR-10 Batch 3:  Loss = 1.4433, Validation Accuracy = 0.448400
# Epoch  8, CIFAR-10 Batch 4:  Loss = 1.4287, Validation Accuracy = 0.461000
# Epoch  8, CIFAR-10 Batch 5:  Loss = 1.4573, Validation Accuracy = 0.459200
# Epoch  9, CIFAR-10 Batch 1:  Loss = 1.4583, Validation Accuracy = 0.470600
# Epoch  9, CIFAR-10 Batch 2:  Loss = 1.4700, Validation Accuracy = 0.465200
# Epoch  9, CIFAR-10 Batch 3:  Loss = 1.4101, Validation Accuracy = 0.464200
# Epoch  9, CIFAR-10 Batch 4:  Loss = 1.3884, Validation Accuracy = 0.473400
# Epoch  9, CIFAR-10 Batch 5:  Loss = 1.4256, Validation Accuracy = 0.476600
# Epoch 10, CIFAR-10 Batch 1:  Loss = 1.4222, Validation Accuracy = 0.485400
# Epoch 10, CIFAR-10 Batch 2:  Loss = 1.4395, Validation Accuracy = 0.489200
# Epoch 10, CIFAR-10 Batch 3:  Loss = 1.3596, Validation Accuracy = 0.480400
# Epoch 10, CIFAR-10 Batch 4:  Loss = 1.3552, Validation Accuracy = 0.486600
# Epoch 10, CIFAR-10 Batch 5:  Loss = 1.3838, Validation Accuracy = 0.492000
# Epoch 11, CIFAR-10 Batch 1:  Loss = 1.3949, Validation Accuracy = 0.488000
# Epoch 11, CIFAR-10 Batch 2:  Loss = 1.4207, Validation Accuracy = 0.492400
# Epoch 11, CIFAR-10 Batch 3:  Loss = 1.3286, Validation Accuracy = 0.490800
# Epoch 11, CIFAR-10 Batch 4:  Loss = 1.3340, Validation Accuracy = 0.496200
# Epoch 11, CIFAR-10 Batch 5:  Loss = 1.3546, Validation Accuracy = 0.505400
# Epoch 12, CIFAR-10 Batch 1:  Loss = 1.3693, Validation Accuracy = 0.501600
# Epoch 12, CIFAR-10 Batch 2:  Loss = 1.3944, Validation Accuracy = 0.504400
# Epoch 12, CIFAR-10 Batch 3:  Loss = 1.3035, Validation Accuracy = 0.491800
# Epoch 12, CIFAR-10 Batch 4:  Loss = 1.3120, Validation Accuracy = 0.504200
# Epoch 12, CIFAR-10 Batch 5:  Loss = 1.3442, Validation Accuracy = 0.500800
# Epoch 13, CIFAR-10 Batch 1:  Loss = 1.3493, Validation Accuracy = 0.507600
# Epoch 13, CIFAR-10 Batch 2:  Loss = 1.3599, Validation Accuracy = 0.503800
# Epoch 13, CIFAR-10 Batch 3:  Loss = 1.2909, Validation Accuracy = 0.508600
# Epoch 13, CIFAR-10 Batch 4:  Loss = 1.2760, Validation Accuracy = 0.514600
# Epoch 13, CIFAR-10 Batch 5:  Loss = 1.3079, Validation Accuracy = 0.514000
# Epoch 14, CIFAR-10 Batch 1:  Loss = 1.3257, Validation Accuracy = 0.513800
# Epoch 14, CIFAR-10 Batch 2:  Loss = 1.3656, Validation Accuracy = 0.503200
# Epoch 14, CIFAR-10 Batch 3:  Loss = 1.2720, Validation Accuracy = 0.513000
# Epoch 14, CIFAR-10 Batch 4:  Loss = 1.2565, Validation Accuracy = 0.517400
# Epoch 14, CIFAR-10 Batch 5:  Loss = 1.2851, Validation Accuracy = 0.517800
# Epoch 15, CIFAR-10 Batch 1:  Loss = 1.3315, Validation Accuracy = 0.506400
# Epoch 15, CIFAR-10 Batch 2:  Loss = 1.3415, Validation Accuracy = 0.508200
# Epoch 15, CIFAR-10 Batch 3:  Loss = 1.2690, Validation Accuracy = 0.503600
# Epoch 15, CIFAR-10 Batch 4:  Loss = 1.2540, Validation Accuracy = 0.524200
# Epoch 15, CIFAR-10 Batch 5:  Loss = 1.2743, Validation Accuracy = 0.524000
# Epoch 16, CIFAR-10 Batch 1:  Loss = 1.2929, Validation Accuracy = 0.522200
# Epoch 16, CIFAR-10 Batch 2:  Loss = 1.3000, Validation Accuracy = 0.523000
# Epoch 16, CIFAR-10 Batch 3:  Loss = 1.2520, Validation Accuracy = 0.508400
# Epoch 16, CIFAR-10 Batch 4:  Loss = 1.2418, Validation Accuracy = 0.527400
# Epoch 16, CIFAR-10 Batch 5:  Loss = 1.2433, Validation Accuracy = 0.528200
# Epoch 17, CIFAR-10 Batch 1:  Loss = 1.2684, Validation Accuracy = 0.538000
# Epoch 17, CIFAR-10 Batch 2:  Loss = 1.2914, Validation Accuracy = 0.527200
# Epoch 17, CIFAR-10 Batch 3:  Loss = 1.2353, Validation Accuracy = 0.519800
# Epoch 17, CIFAR-10 Batch 4:  Loss = 1.2132, Validation Accuracy = 0.539000
# Epoch 17, CIFAR-10 Batch 5:  Loss = 1.2403, Validation Accuracy = 0.532400
# Epoch 18, CIFAR-10 Batch 1:  Loss = 1.2493, Validation Accuracy = 0.540600
# Epoch 18, CIFAR-10 Batch 2:  Loss = 1.2726, Validation Accuracy = 0.531000
# Epoch 18, CIFAR-10 Batch 3:  Loss = 1.2301, Validation Accuracy = 0.531000
# Epoch 18, CIFAR-10 Batch 4:  Loss = 1.1929, Validation Accuracy = 0.539000
# Epoch 18, CIFAR-10 Batch 5:  Loss = 1.2212, Validation Accuracy = 0.533000
# Epoch 19, CIFAR-10 Batch 1:  Loss = 1.2257, Validation Accuracy = 0.540000
# Epoch 19, CIFAR-10 Batch 2:  Loss = 1.2511, Validation Accuracy = 0.537000
# Epoch 19, CIFAR-10 Batch 3:  Loss = 1.2066, Validation Accuracy = 0.533400
# Epoch 19, CIFAR-10 Batch 4:  Loss = 1.1948, Validation Accuracy = 0.542800
# Epoch 19, CIFAR-10 Batch 5:  Loss = 1.2161, Validation Accuracy = 0.541000
# Epoch 20, CIFAR-10 Batch 1:  Loss = 1.2163, Validation Accuracy = 0.544800
# Epoch 20, CIFAR-10 Batch 2:  Loss = 1.2510, Validation Accuracy = 0.537000
# Epoch 20, CIFAR-10 Batch 3:  Loss = 1.2103, Validation Accuracy = 0.533400
# Epoch 20, CIFAR-10 Batch 4:  Loss = 1.1918, Validation Accuracy = 0.539400
# Epoch 20, CIFAR-10 Batch 5:  Loss = 1.2025, Validation Accuracy = 0.538800
# Epoch 21, CIFAR-10 Batch 1:  Loss = 1.1987, Validation Accuracy = 0.548400
# Epoch 21, CIFAR-10 Batch 2:  Loss = 1.2206, Validation Accuracy = 0.542400
# Epoch 21, CIFAR-10 Batch 3:  Loss = 1.1947, Validation Accuracy = 0.530400
# Epoch 21, CIFAR-10 Batch 4:  Loss = 1.1689, Validation Accuracy = 0.546600
# Epoch 21, CIFAR-10 Batch 5:  Loss = 1.1662, Validation Accuracy = 0.540000
# Epoch 22, CIFAR-10 Batch 1:  Loss = 1.1986, Validation Accuracy = 0.544200
# Epoch 22, CIFAR-10 Batch 2:  Loss = 1.2162, Validation Accuracy = 0.540200
# Epoch 22, CIFAR-10 Batch 3:  Loss = 1.1744, Validation Accuracy = 0.541800
# Epoch 22, CIFAR-10 Batch 4:  Loss = 1.1425, Validation Accuracy = 0.554200
# Epoch 22, CIFAR-10 Batch 5:  Loss = 1.1702, Validation Accuracy = 0.540800
# Epoch 23, CIFAR-10 Batch 1:  Loss = 1.1821, Validation Accuracy = 0.546600
# Epoch 23, CIFAR-10 Batch 2:  Loss = 1.1965, Validation Accuracy = 0.548000
# Epoch 23, CIFAR-10 Batch 3:  Loss = 1.1650, Validation Accuracy = 0.551200
# Epoch 23, CIFAR-10 Batch 4:  Loss = 1.1311, Validation Accuracy = 0.562200
# Epoch 23, CIFAR-10 Batch 5:  Loss = 1.1608, Validation Accuracy = 0.548600
# Epoch 24, CIFAR-10 Batch 1:  Loss = 1.1797, Validation Accuracy = 0.545000
# Epoch 24, CIFAR-10 Batch 2:  Loss = 1.1946, Validation Accuracy = 0.545800
# Epoch 24, CIFAR-10 Batch 3:  Loss = 1.1446, Validation Accuracy = 0.551800
# Epoch 24, CIFAR-10 Batch 4:  Loss = 1.1227, Validation Accuracy = 0.561800
# Epoch 24, CIFAR-10 Batch 5:  Loss = 1.1503, Validation Accuracy = 0.553600
# Epoch 25, CIFAR-10 Batch 1:  Loss = 1.1673, Validation Accuracy = 0.553400
# Epoch 25, CIFAR-10 Batch 2:  Loss = 1.1732, Validation Accuracy = 0.550600
# Epoch 25, CIFAR-10 Batch 3:  Loss = 1.1322, Validation Accuracy = 0.556400
# Epoch 25, CIFAR-10 Batch 4:  Loss = 1.1184, Validation Accuracy = 0.557200
# Epoch 25, CIFAR-10 Batch 5:  Loss = 1.1285, Validation Accuracy = 0.549000
# Epoch 26, CIFAR-10 Batch 1:  Loss = 1.1575, Validation Accuracy = 0.554400
# Epoch 26, CIFAR-10 Batch 2:  Loss = 1.1761, Validation Accuracy = 0.549800
# Epoch 26, CIFAR-10 Batch 3:  Loss = 1.1399, Validation Accuracy = 0.545400
# Epoch 26, CIFAR-10 Batch 4:  Loss = 1.1125, Validation Accuracy = 0.562800
# Epoch 26, CIFAR-10 Batch 5:  Loss = 1.1284, Validation Accuracy = 0.559800
# Epoch 27, CIFAR-10 Batch 1:  Loss = 1.1445, Validation Accuracy = 0.561600
# Epoch 27, CIFAR-10 Batch 2:  Loss = 1.1759, Validation Accuracy = 0.549600
# Epoch 27, CIFAR-10 Batch 3:  Loss = 1.1300, Validation Accuracy = 0.556400
# Epoch 27, CIFAR-10 Batch 4:  Loss = 1.0953, Validation Accuracy = 0.566400
# Epoch 27, CIFAR-10 Batch 5:  Loss = 1.1265, Validation Accuracy = 0.545400
# Epoch 28, CIFAR-10 Batch 1:  Loss = 1.1162, Validation Accuracy = 0.562800
# Epoch 28, CIFAR-10 Batch 2:  Loss = 1.1493, Validation Accuracy = 0.555000
# Epoch 28, CIFAR-10 Batch 3:  Loss = 1.1134, Validation Accuracy = 0.560400
# Epoch 28, CIFAR-10 Batch 4:  Loss = 1.0961, Validation Accuracy = 0.571600
# Epoch 28, CIFAR-10 Batch 5:  Loss = 1.1005, Validation Accuracy = 0.562200
# Epoch 29, CIFAR-10 Batch 1:  Loss = 1.1064, Validation Accuracy = 0.563600
# Epoch 29, CIFAR-10 Batch 2:  Loss = 1.1528, Validation Accuracy = 0.554200
# Epoch 29, CIFAR-10 Batch 3:  Loss = 1.0999, Validation Accuracy = 0.556200
# Epoch 29, CIFAR-10 Batch 4:  Loss = 1.0799, Validation Accuracy = 0.571000
# Epoch 29, CIFAR-10 Batch 5:  Loss = 1.1120, Validation Accuracy = 0.562200
# Epoch 30, CIFAR-10 Batch 1:  Loss = 1.0744, Validation Accuracy = 0.565400
# Epoch 30, CIFAR-10 Batch 2:  Loss = 1.1407, Validation Accuracy = 0.560400
# Epoch 30, CIFAR-10 Batch 3:  Loss = 1.1174, Validation Accuracy = 0.552400
# Epoch 30, CIFAR-10 Batch 4:  Loss = 1.0788, Validation Accuracy = 0.563000
# Epoch 30, CIFAR-10 Batch 5:  Loss = 1.1185, Validation Accuracy = 0.557000
# Epoch 31, CIFAR-10 Batch 1:  Loss = 1.0849, Validation Accuracy = 0.570000
# Epoch 31, CIFAR-10 Batch 2:  Loss = 1.1225, Validation Accuracy = 0.559000
# Epoch 31, CIFAR-10 Batch 3:  Loss = 1.1260, Validation Accuracy = 0.556800
# Epoch 31, CIFAR-10 Batch 4:  Loss = 1.0948, Validation Accuracy = 0.559600
# Epoch 31, CIFAR-10 Batch 5:  Loss = 1.0948, Validation Accuracy = 0.560800
# Epoch 32, CIFAR-10 Batch 1:  Loss = 1.0733, Validation Accuracy = 0.570200
# Epoch 32, CIFAR-10 Batch 2:  Loss = 1.1181, Validation Accuracy = 0.554200
# Epoch 32, CIFAR-10 Batch 3:  Loss = 1.0838, Validation Accuracy = 0.563200
# Epoch 32, CIFAR-10 Batch 4:  Loss = 1.0685, Validation Accuracy = 0.577400
# Epoch 32, CIFAR-10 Batch 5:  Loss = 1.0743, Validation Accuracy = 0.563400
# Epoch 33, CIFAR-10 Batch 1:  Loss = 1.0737, Validation Accuracy = 0.570400
# Epoch 33, CIFAR-10 Batch 2:  Loss = 1.0869, Validation Accuracy = 0.568200
# Epoch 33, CIFAR-10 Batch 3:  Loss = 1.0641, Validation Accuracy = 0.569800
# Epoch 33, CIFAR-10 Batch 4:  Loss = 1.0348, Validation Accuracy = 0.579400
# Epoch 33, CIFAR-10 Batch 5:  Loss = 1.0583, Validation Accuracy = 0.561800
# Epoch 34, CIFAR-10 Batch 1:  Loss = 1.0624, Validation Accuracy = 0.574600
# Epoch 34, CIFAR-10 Batch 2:  Loss = 1.0830, Validation Accuracy = 0.561800
# Epoch 34, CIFAR-10 Batch 3:  Loss = 1.0431, Validation Accuracy = 0.578200
# Epoch 34, CIFAR-10 Batch 4:  Loss = 1.0257, Validation Accuracy = 0.582200
# Epoch 34, CIFAR-10 Batch 5:  Loss = 1.0707, Validation Accuracy = 0.561800
# Epoch 35, CIFAR-10 Batch 1:  Loss = 1.0552, Validation Accuracy = 0.573000
# Epoch 35, CIFAR-10 Batch 2:  Loss = 1.0680, Validation Accuracy = 0.570000
# Epoch 35, CIFAR-10 Batch 3:  Loss = 1.0444, Validation Accuracy = 0.580000
# Epoch 35, CIFAR-10 Batch 4:  Loss = 1.0312, Validation Accuracy = 0.581200
# Epoch 35, CIFAR-10 Batch 5:  Loss = 1.0261, Validation Accuracy = 0.577800
# Epoch 36, CIFAR-10 Batch 1:  Loss = 1.0385, Validation Accuracy = 0.577600
# Epoch 36, CIFAR-10 Batch 2:  Loss = 1.0538, Validation Accuracy = 0.570600
# Epoch 36, CIFAR-10 Batch 3:  Loss = 1.0194, Validation Accuracy = 0.577600
# Epoch 36, CIFAR-10 Batch 4:  Loss = 1.0177, Validation Accuracy = 0.579600
# Epoch 36, CIFAR-10 Batch 5:  Loss = 1.0273, Validation Accuracy = 0.579200
# Epoch 37, CIFAR-10 Batch 1:  Loss = 1.0278, Validation Accuracy = 0.577800
# Epoch 37, CIFAR-10 Batch 2:  Loss = 1.0628, Validation Accuracy = 0.562200
# Epoch 37, CIFAR-10 Batch 3:  Loss = 1.0277, Validation Accuracy = 0.578200
# Epoch 37, CIFAR-10 Batch 4:  Loss = 0.9992, Validation Accuracy = 0.589200
# Epoch 37, CIFAR-10 Batch 5:  Loss = 1.0245, Validation Accuracy = 0.574600
# Epoch 38, CIFAR-10 Batch 1:  Loss = 1.0225, Validation Accuracy = 0.585000
# Epoch 38, CIFAR-10 Batch 2:  Loss = 1.0552, Validation Accuracy = 0.568400
# Epoch 38, CIFAR-10 Batch 3:  Loss = 1.0404, Validation Accuracy = 0.579200
# Epoch 38, CIFAR-10 Batch 4:  Loss = 1.0070, Validation Accuracy = 0.587200
# Epoch 38, CIFAR-10 Batch 5:  Loss = 1.0417, Validation Accuracy = 0.568000
# Epoch 39, CIFAR-10 Batch 1:  Loss = 1.0114, Validation Accuracy = 0.582400
# Epoch 39, CIFAR-10 Batch 2:  Loss = 1.0282, Validation Accuracy = 0.582000
# Epoch 39, CIFAR-10 Batch 3:  Loss = 1.0251, Validation Accuracy = 0.582200
# Epoch 39, CIFAR-10 Batch 4:  Loss = 0.9957, Validation Accuracy = 0.583200
# Epoch 39, CIFAR-10 Batch 5:  Loss = 1.0008, Validation Accuracy = 0.577600
# Epoch 40, CIFAR-10 Batch 1:  Loss = 1.0078, Validation Accuracy = 0.584400
# Epoch 40, CIFAR-10 Batch 2:  Loss = 1.0295, Validation Accuracy = 0.577000
# Epoch 40, CIFAR-10 Batch 3:  Loss = 1.0042, Validation Accuracy = 0.586000
# Epoch 40, CIFAR-10 Batch 4:  Loss = 0.9948, Validation Accuracy = 0.580400
# Epoch 40, CIFAR-10 Batch 5:  Loss = 1.0065, Validation Accuracy = 0.577200
# Epoch 41, CIFAR-10 Batch 1:  Loss = 0.9917, Validation Accuracy = 0.585800
# Epoch 41, CIFAR-10 Batch 2:  Loss = 1.0265, Validation Accuracy = 0.574600
# Epoch 41, CIFAR-10 Batch 3:  Loss = 1.0051, Validation Accuracy = 0.581200
# Epoch 41, CIFAR-10 Batch 4:  Loss = 0.9801, Validation Accuracy = 0.582200
# Epoch 41, CIFAR-10 Batch 5:  Loss = 0.9884, Validation Accuracy = 0.576600
# Epoch 42, CIFAR-10 Batch 1:  Loss = 0.9865, Validation Accuracy = 0.590000
# Epoch 42, CIFAR-10 Batch 2:  Loss = 1.0336, Validation Accuracy = 0.578400
# Epoch 42, CIFAR-10 Batch 3:  Loss = 1.0028, Validation Accuracy = 0.587000
# Epoch 42, CIFAR-10 Batch 4:  Loss = 0.9655, Validation Accuracy = 0.589800
# Epoch 42, CIFAR-10 Batch 5:  Loss = 0.9768, Validation Accuracy = 0.584800
# Epoch 43, CIFAR-10 Batch 1:  Loss = 0.9793, Validation Accuracy = 0.582800
# Epoch 43, CIFAR-10 Batch 2:  Loss = 1.0512, Validation Accuracy = 0.561000
# Epoch 43, CIFAR-10 Batch 3:  Loss = 0.9928, Validation Accuracy = 0.587000
# Epoch 43, CIFAR-10 Batch 4:  Loss = 0.9754, Validation Accuracy = 0.589800
# Epoch 43, CIFAR-10 Batch 5:  Loss = 0.9806, Validation Accuracy = 0.583200
# Epoch 44, CIFAR-10 Batch 1:  Loss = 0.9880, Validation Accuracy = 0.580800
# Epoch 44, CIFAR-10 Batch 2:  Loss = 1.0479, Validation Accuracy = 0.557000
# Epoch 44, CIFAR-10 Batch 3:  Loss = 1.0092, Validation Accuracy = 0.572800
# Epoch 44, CIFAR-10 Batch 4:  Loss = 1.0107, Validation Accuracy = 0.567400
# Epoch 44, CIFAR-10 Batch 5:  Loss = 0.9874, Validation Accuracy = 0.579200
# Epoch 45, CIFAR-10 Batch 1:  Loss = 1.0424, Validation Accuracy = 0.558000
# Epoch 45, CIFAR-10 Batch 2:  Loss = 1.0081, Validation Accuracy = 0.589400
# Epoch 45, CIFAR-10 Batch 3:  Loss = 1.0055, Validation Accuracy = 0.577000
# Epoch 45, CIFAR-10 Batch 4:  Loss = 1.0290, Validation Accuracy = 0.556400
# Epoch 45, CIFAR-10 Batch 5:  Loss = 0.9769, Validation Accuracy = 0.581400
# Epoch 46, CIFAR-10 Batch 1:  Loss = 1.0324, Validation Accuracy = 0.568400
# Epoch 46, CIFAR-10 Batch 2:  Loss = 1.0015, Validation Accuracy = 0.580200
# Epoch 46, CIFAR-10 Batch 3:  Loss = 0.9789, Validation Accuracy = 0.584600
# Epoch 46, CIFAR-10 Batch 4:  Loss = 0.9875, Validation Accuracy = 0.575000
# Epoch 46, CIFAR-10 Batch 5:  Loss = 0.9710, Validation Accuracy = 0.581600
# Epoch 47, CIFAR-10 Batch 1:  Loss = 1.0003, Validation Accuracy = 0.571400
# Epoch 47, CIFAR-10 Batch 2:  Loss = 0.9919, Validation Accuracy = 0.589200
# Epoch 47, CIFAR-10 Batch 3:  Loss = 0.9615, Validation Accuracy = 0.591400
# Epoch 47, CIFAR-10 Batch 4:  Loss = 0.9458, Validation Accuracy = 0.597400
# Epoch 47, CIFAR-10 Batch 5:  Loss = 0.9563, Validation Accuracy = 0.591000
# Epoch 48, CIFAR-10 Batch 1:  Loss = 1.0132, Validation Accuracy = 0.561600
# Epoch 48, CIFAR-10 Batch 2:  Loss = 0.9751, Validation Accuracy = 0.594600
# Epoch 48, CIFAR-10 Batch 3:  Loss = 0.9611, Validation Accuracy = 0.589800
# Epoch 48, CIFAR-10 Batch 4:  Loss = 0.9759, Validation Accuracy = 0.581000
# Epoch 48, CIFAR-10 Batch 5:  Loss = 0.9639, Validation Accuracy = 0.574400
# Epoch 49, CIFAR-10 Batch 1:  Loss = 1.0013, Validation Accuracy = 0.565000
# Epoch 49, CIFAR-10 Batch 2:  Loss = 0.9909, Validation Accuracy = 0.588000
# Epoch 49, CIFAR-10 Batch 3:  Loss = 0.9643, Validation Accuracy = 0.589200
# Epoch 49, CIFAR-10 Batch 4:  Loss = 0.9458, Validation Accuracy = 0.596400
# Epoch 49, CIFAR-10 Batch 5:  Loss = 0.9587, Validation Accuracy = 0.583400
# Epoch 50, CIFAR-10 Batch 1:  Loss = 0.9987, Validation Accuracy = 0.571400
# Epoch 50, CIFAR-10 Batch 2:  Loss = 0.9816, Validation Accuracy = 0.584600
# Epoch 50, CIFAR-10 Batch 3:  Loss = 0.9740, Validation Accuracy = 0.584800
# Epoch 50, CIFAR-10 Batch 4:  Loss = 0.9598, Validation Accuracy = 0.584000
# Epoch 50, CIFAR-10 Batch 5:  Loss = 0.9355, Validation Accuracy = 0.591000
# Epoch 51, CIFAR-10 Batch 1:  Loss = 0.9859, Validation Accuracy = 0.580600
# Epoch 51, CIFAR-10 Batch 2:  Loss = 0.9756, Validation Accuracy = 0.587600
# Epoch 51, CIFAR-10 Batch 3:  Loss = 0.9481, Validation Accuracy = 0.591200
# Epoch 51, CIFAR-10 Batch 4:  Loss = 0.9263, Validation Accuracy = 0.598200
# Epoch 51, CIFAR-10 Batch 5:  Loss = 0.9365, Validation Accuracy = 0.592000
# Epoch 52, CIFAR-10 Batch 1:  Loss = 0.9907, Validation Accuracy = 0.576000
# Epoch 52, CIFAR-10 Batch 2:  Loss = 0.9638, Validation Accuracy = 0.586800
# Epoch 52, CIFAR-10 Batch 3:  Loss = 0.9522, Validation Accuracy = 0.585800
# Epoch 52, CIFAR-10 Batch 4:  Loss = 0.9190, Validation Accuracy = 0.603400
# Epoch 52, CIFAR-10 Batch 5:  Loss = 0.9454, Validation Accuracy = 0.582200
# Epoch 53, CIFAR-10 Batch 1:  Loss = 1.0050, Validation Accuracy = 0.560600
# Epoch 53, CIFAR-10 Batch 2:  Loss = 0.9517, Validation Accuracy = 0.590400
# Epoch 53, CIFAR-10 Batch 3:  Loss = 0.9394, Validation Accuracy = 0.584200
# Epoch 53, CIFAR-10 Batch 4:  Loss = 0.9502, Validation Accuracy = 0.570400
# Epoch 53, CIFAR-10 Batch 5:  Loss = 0.9214, Validation Accuracy = 0.594000
# Epoch 54, CIFAR-10 Batch 1:  Loss = 0.9510, Validation Accuracy = 0.593800
# Epoch 54, CIFAR-10 Batch 2:  Loss = 0.9549, Validation Accuracy = 0.593000
# Epoch 54, CIFAR-10 Batch 3:  Loss = 0.9537, Validation Accuracy = 0.581800
# Epoch 54, CIFAR-10 Batch 4:  Loss = 0.9343, Validation Accuracy = 0.579000
# Epoch 54, CIFAR-10 Batch 5:  Loss = 0.9175, Validation Accuracy = 0.593800
# Epoch 55, CIFAR-10 Batch 1:  Loss = 0.9264, Validation Accuracy = 0.598000
# Epoch 55, CIFAR-10 Batch 2:  Loss = 0.9790, Validation Accuracy = 0.574600
# Epoch 55, CIFAR-10 Batch 3:  Loss = 0.9363, Validation Accuracy = 0.591600
# Epoch 55, CIFAR-10 Batch 4:  Loss = 0.9317, Validation Accuracy = 0.587400
# Epoch 55, CIFAR-10 Batch 5:  Loss = 0.9618, Validation Accuracy = 0.576800
# Epoch 56, CIFAR-10 Batch 1:  Loss = 0.9371, Validation Accuracy = 0.585800
# Epoch 56, CIFAR-10 Batch 2:  Loss = 0.9322, Validation Accuracy = 0.593600
# Epoch 56, CIFAR-10 Batch 3:  Loss = 0.9094, Validation Accuracy = 0.594800
# Epoch 56, CIFAR-10 Batch 4:  Loss = 0.8973, Validation Accuracy = 0.595800
# Epoch 56, CIFAR-10 Batch 5:  Loss = 0.9166, Validation Accuracy = 0.596000
# Epoch 57, CIFAR-10 Batch 1:  Loss = 0.9263, Validation Accuracy = 0.591600
# Epoch 57, CIFAR-10 Batch 2:  Loss = 0.9443, Validation Accuracy = 0.583800
# Epoch 57, CIFAR-10 Batch 3:  Loss = 0.9288, Validation Accuracy = 0.586000
# Epoch 57, CIFAR-10 Batch 4:  Loss = 0.9142, Validation Accuracy = 0.591200
# Epoch 57, CIFAR-10 Batch 5:  Loss = 0.9418, Validation Accuracy = 0.580200
# Epoch 58, CIFAR-10 Batch 1:  Loss = 0.9246, Validation Accuracy = 0.596600
# Epoch 58, CIFAR-10 Batch 2:  Loss = 0.9226, Validation Accuracy = 0.594000
# Epoch 58, CIFAR-10 Batch 3:  Loss = 0.9135, Validation Accuracy = 0.592400
# Epoch 58, CIFAR-10 Batch 4:  Loss = 0.9041, Validation Accuracy = 0.592800
# Epoch 58, CIFAR-10 Batch 5:  Loss = 0.9169, Validation Accuracy = 0.589800
# Epoch 59, CIFAR-10 Batch 1:  Loss = 0.9063, Validation Accuracy = 0.600400
# Epoch 59, CIFAR-10 Batch 2:  Loss = 0.9090, Validation Accuracy = 0.597200
# Epoch 59, CIFAR-10 Batch 3:  Loss = 0.9039, Validation Accuracy = 0.590400
# Epoch 59, CIFAR-10 Batch 4:  Loss = 0.8826, Validation Accuracy = 0.588200
# Epoch 59, CIFAR-10 Batch 5:  Loss = 0.8948, Validation Accuracy = 0.594800
# Epoch 60, CIFAR-10 Batch 1:  Loss = 0.8913, Validation Accuracy = 0.593800
# Epoch 60, CIFAR-10 Batch 2:  Loss = 0.9131, Validation Accuracy = 0.596400
# Epoch 60, CIFAR-10 Batch 3:  Loss = 0.8989, Validation Accuracy = 0.587200
# Epoch 60, CIFAR-10 Batch 4:  Loss = 0.8717, Validation Accuracy = 0.600000
# Epoch 60, CIFAR-10 Batch 5:  Loss = 0.8847, Validation Accuracy = 0.596200
# Epoch 61, CIFAR-10 Batch 1:  Loss = 0.8988, Validation Accuracy = 0.595600
# Epoch 61, CIFAR-10 Batch 2:  Loss = 0.9100, Validation Accuracy = 0.587200
# Epoch 61, CIFAR-10 Batch 3:  Loss = 0.8783, Validation Accuracy = 0.600000
# Epoch 61, CIFAR-10 Batch 4:  Loss = 0.8872, Validation Accuracy = 0.593800
# Epoch 61, CIFAR-10 Batch 5:  Loss = 0.8853, Validation Accuracy = 0.595400
# Epoch 62, CIFAR-10 Batch 1:  Loss = 0.9290, Validation Accuracy = 0.584200
# Epoch 62, CIFAR-10 Batch 2:  Loss = 0.9516, Validation Accuracy = 0.580800
# Epoch 62, CIFAR-10 Batch 3:  Loss = 0.8979, Validation Accuracy = 0.585600
# Epoch 62, CIFAR-10 Batch 4:  Loss = 0.9145, Validation Accuracy = 0.574800
# Epoch 62, CIFAR-10 Batch 5:  Loss = 0.8775, Validation Accuracy = 0.591800
# Epoch 63, CIFAR-10 Batch 1:  Loss = 0.9188, Validation Accuracy = 0.583800
# Epoch 63, CIFAR-10 Batch 2:  Loss = 0.9146, Validation Accuracy = 0.590800
# Epoch 63, CIFAR-10 Batch 3:  Loss = 0.8894, Validation Accuracy = 0.594400
# Epoch 63, CIFAR-10 Batch 4:  Loss = 0.8697, Validation Accuracy = 0.593400
# Epoch 63, CIFAR-10 Batch 5:  Loss = 0.8853, Validation Accuracy = 0.583800
# Epoch 64, CIFAR-10 Batch 1:  Loss = 0.8973, Validation Accuracy = 0.590000
# Epoch 64, CIFAR-10 Batch 2:  Loss = 0.8979, Validation Accuracy = 0.596000
# Epoch 64, CIFAR-10 Batch 3:  Loss = 0.8651, Validation Accuracy = 0.597800
# Epoch 64, CIFAR-10 Batch 4:  Loss = 0.8651, Validation Accuracy = 0.591200
# Epoch 64, CIFAR-10 Batch 5:  Loss = 0.8559, Validation Accuracy = 0.596200
# Epoch 65, CIFAR-10 Batch 1:  Loss = 0.8857, Validation Accuracy = 0.586000
# Epoch 65, CIFAR-10 Batch 2:  Loss = 0.8806, Validation Accuracy = 0.596800
# Epoch 65, CIFAR-10 Batch 3:  Loss = 0.8749, Validation Accuracy = 0.595200
# Epoch 65, CIFAR-10 Batch 4:  Loss = 0.8559, Validation Accuracy = 0.599200
# Epoch 65, CIFAR-10 Batch 5:  Loss = 0.8578, Validation Accuracy = 0.599000
# Epoch 66, CIFAR-10 Batch 1:  Loss = 0.8883, Validation Accuracy = 0.591000
# Epoch 66, CIFAR-10 Batch 2:  Loss = 0.8869, Validation Accuracy = 0.593400
# Epoch 66, CIFAR-10 Batch 3:  Loss = 0.8474, Validation Accuracy = 0.599000
# Epoch 66, CIFAR-10 Batch 4:  Loss = 0.8411, Validation Accuracy = 0.595600
# Epoch 66, CIFAR-10 Batch 5:  Loss = 0.8416, Validation Accuracy = 0.606400
# Epoch 67, CIFAR-10 Batch 1:  Loss = 0.8711, Validation Accuracy = 0.601400
# Epoch 67, CIFAR-10 Batch 2:  Loss = 0.8831, Validation Accuracy = 0.592000
# Epoch 67, CIFAR-10 Batch 3:  Loss = 0.8538, Validation Accuracy = 0.593400
# Epoch 67, CIFAR-10 Batch 4:  Loss = 0.8385, Validation Accuracy = 0.594200
# Epoch 67, CIFAR-10 Batch 5:  Loss = 0.8320, Validation Accuracy = 0.599600
# Epoch 68, CIFAR-10 Batch 1:  Loss = 0.8545, Validation Accuracy = 0.600200
# Epoch 68, CIFAR-10 Batch 2:  Loss = 0.8693, Validation Accuracy = 0.594600
# Epoch 68, CIFAR-10 Batch 3:  Loss = 0.8387, Validation Accuracy = 0.597000
# Epoch 68, CIFAR-10 Batch 4:  Loss = 0.8686, Validation Accuracy = 0.576800
# Epoch 68, CIFAR-10 Batch 5:  Loss = 0.8422, Validation Accuracy = 0.587200
# Epoch 69, CIFAR-10 Batch 1:  Loss = 0.8461, Validation Accuracy = 0.602200
# Epoch 69, CIFAR-10 Batch 2:  Loss = 0.8676, Validation Accuracy = 0.581800
# Epoch 69, CIFAR-10 Batch 3:  Loss = 0.8497, Validation Accuracy = 0.594400
# Epoch 69, CIFAR-10 Batch 4:  Loss = 0.8507, Validation Accuracy = 0.587000
# Epoch 69, CIFAR-10 Batch 5:  Loss = 0.8413, Validation Accuracy = 0.594600
# Epoch 70, CIFAR-10 Batch 1:  Loss = 0.8603, Validation Accuracy = 0.591000
# Epoch 70, CIFAR-10 Batch 2:  Loss = 0.8833, Validation Accuracy = 0.584600
# Epoch 70, CIFAR-10 Batch 3:  Loss = 0.8474, Validation Accuracy = 0.604000
# Epoch 70, CIFAR-10 Batch 4:  Loss = 0.8278, Validation Accuracy = 0.593000
# Epoch 70, CIFAR-10 Batch 5:  Loss = 0.8324, Validation Accuracy = 0.595400
# Epoch 71, CIFAR-10 Batch 1:  Loss = 0.8675, Validation Accuracy = 0.590200
# Epoch 71, CIFAR-10 Batch 2:  Loss = 0.9480, Validation Accuracy = 0.565000
# Epoch 71, CIFAR-10 Batch 3:  Loss = 0.8692, Validation Accuracy = 0.589400
# Epoch 71, CIFAR-10 Batch 4:  Loss = 0.8283, Validation Accuracy = 0.600400
# Epoch 71, CIFAR-10 Batch 5:  Loss = 0.8644, Validation Accuracy = 0.577000
# Epoch 72, CIFAR-10 Batch 1:  Loss = 0.8910, Validation Accuracy = 0.570600
# Epoch 72, CIFAR-10 Batch 2:  Loss = 0.8740, Validation Accuracy = 0.587400
# Epoch 72, CIFAR-10 Batch 3:  Loss = 0.8298, Validation Accuracy = 0.597400
# Epoch 72, CIFAR-10 Batch 4:  Loss = 0.8278, Validation Accuracy = 0.591600
# Epoch 72, CIFAR-10 Batch 5:  Loss = 0.8400, Validation Accuracy = 0.580400
# Epoch 73, CIFAR-10 Batch 1:  Loss = 0.8684, Validation Accuracy = 0.577600
# Epoch 73, CIFAR-10 Batch 2:  Loss = 0.8877, Validation Accuracy = 0.573400
# Epoch 73, CIFAR-10 Batch 3:  Loss = 0.8442, Validation Accuracy = 0.594400
# Epoch 73, CIFAR-10 Batch 4:  Loss = 0.8352, Validation Accuracy = 0.590000
# Epoch 73, CIFAR-10 Batch 5:  Loss = 0.8325, Validation Accuracy = 0.579000
# Epoch 74, CIFAR-10 Batch 1:  Loss = 0.9039, Validation Accuracy = 0.558000
# Epoch 74, CIFAR-10 Batch 2:  Loss = 0.9091, Validation Accuracy = 0.574400
# Epoch 74, CIFAR-10 Batch 3:  Loss = 0.8488, Validation Accuracy = 0.593600
# Epoch 74, CIFAR-10 Batch 4:  Loss = 0.8306, Validation Accuracy = 0.596600
# Epoch 74, CIFAR-10 Batch 5:  Loss = 0.8397, Validation Accuracy = 0.581400
# Epoch 75, CIFAR-10 Batch 1:  Loss = 0.8550, Validation Accuracy = 0.582600
# Epoch 75, CIFAR-10 Batch 2:  Loss = 0.8538, Validation Accuracy = 0.590800
# Epoch 75, CIFAR-10 Batch 3:  Loss = 0.8307, Validation Accuracy = 0.593800
# Epoch 75, CIFAR-10 Batch 4:  Loss = 0.8092, Validation Accuracy = 0.598600
# Epoch 75, CIFAR-10 Batch 5:  Loss = 0.8482, Validation Accuracy = 0.574600
# Epoch 76, CIFAR-10 Batch 1:  Loss = 0.8455, Validation Accuracy = 0.582200
# Epoch 76, CIFAR-10 Batch 2:  Loss = 0.8497, Validation Accuracy = 0.589800
# Epoch 76, CIFAR-10 Batch 3:  Loss = 0.8233, Validation Accuracy = 0.595800
# Epoch 76, CIFAR-10 Batch 4:  Loss = 0.8112, Validation Accuracy = 0.595800
# Epoch 76, CIFAR-10 Batch 5:  Loss = 0.8414, Validation Accuracy = 0.585200
# Epoch 77, CIFAR-10 Batch 1:  Loss = 0.8469, Validation Accuracy = 0.583000
# Epoch 77, CIFAR-10 Batch 2:  Loss = 0.8521, Validation Accuracy = 0.585800
# Epoch 77, CIFAR-10 Batch 3:  Loss = 0.8252, Validation Accuracy = 0.590800
# Epoch 77, CIFAR-10 Batch 4:  Loss = 0.8304, Validation Accuracy = 0.582600
# Epoch 77, CIFAR-10 Batch 5:  Loss = 0.8326, Validation Accuracy = 0.579400
# Epoch 78, CIFAR-10 Batch 1:  Loss = 0.8473, Validation Accuracy = 0.581600
# Epoch 78, CIFAR-10 Batch 2:  Loss = 0.8724, Validation Accuracy = 0.585200
# Epoch 78, CIFAR-10 Batch 3:  Loss = 0.8557, Validation Accuracy = 0.584200
# Epoch 78, CIFAR-10 Batch 4:  Loss = 0.8679, Validation Accuracy = 0.575200
# Epoch 78, CIFAR-10 Batch 5:  Loss = 0.8281, Validation Accuracy = 0.586200
# Epoch 79, CIFAR-10 Batch 1:  Loss = 0.8881, Validation Accuracy = 0.567200
# Epoch 79, CIFAR-10 Batch 2:  Loss = 0.9378, Validation Accuracy = 0.574000
# Epoch 79, CIFAR-10 Batch 3:  Loss = 0.8884, Validation Accuracy = 0.574400
# Epoch 79, CIFAR-10 Batch 4:  Loss = 0.8551, Validation Accuracy = 0.582200
# Epoch 79, CIFAR-10 Batch 5:  Loss = 0.8610, Validation Accuracy = 0.574200
# Epoch 80, CIFAR-10 Batch 1:  Loss = 0.8844, Validation Accuracy = 0.579800
# Epoch 80, CIFAR-10 Batch 2:  Loss = 0.9750, Validation Accuracy = 0.560200
# Epoch 80, CIFAR-10 Batch 3:  Loss = 0.9335, Validation Accuracy = 0.564400
# Epoch 80, CIFAR-10 Batch 4:  Loss = 0.8457, Validation Accuracy = 0.587600
# Epoch 80, CIFAR-10 Batch 5:  Loss = 0.8211, Validation Accuracy = 0.589200
# Epoch 81, CIFAR-10 Batch 1:  Loss = 0.8371, Validation Accuracy = 0.586400
# Epoch 81, CIFAR-10 Batch 2:  Loss = 0.9088, Validation Accuracy = 0.566400
# Epoch 81, CIFAR-10 Batch 3:  Loss = 0.8829, Validation Accuracy = 0.582200
# Epoch 81, CIFAR-10 Batch 4:  Loss = 0.8414, Validation Accuracy = 0.579600
# Epoch 81, CIFAR-10 Batch 5:  Loss = 0.8146, Validation Accuracy = 0.584400
# Epoch 82, CIFAR-10 Batch 1:  Loss = 0.8397, Validation Accuracy = 0.587000
# Epoch 82, CIFAR-10 Batch 2:  Loss = 0.8768, Validation Accuracy = 0.575000
# Epoch 82, CIFAR-10 Batch 3:  Loss = 0.8330, Validation Accuracy = 0.586400
# Epoch 82, CIFAR-10 Batch 4:  Loss = 0.8104, Validation Accuracy = 0.588800
# Epoch 82, CIFAR-10 Batch 5:  Loss = 0.7995, Validation Accuracy = 0.592800
# Epoch 83, CIFAR-10 Batch 1:  Loss = 0.8314, Validation Accuracy = 0.591400
# Epoch 83, CIFAR-10 Batch 2:  Loss = 0.9187, Validation Accuracy = 0.560200
# Epoch 83, CIFAR-10 Batch 3:  Loss = 0.8743, Validation Accuracy = 0.572000
# Epoch 83, CIFAR-10 Batch 4:  Loss = 0.8324, Validation Accuracy = 0.584200
# Epoch 83, CIFAR-10 Batch 5:  Loss = 0.8149, Validation Accuracy = 0.581000
# Epoch 84, CIFAR-10 Batch 1:  Loss = 0.8179, Validation Accuracy = 0.589600
# Epoch 84, CIFAR-10 Batch 2:  Loss = 0.8744, Validation Accuracy = 0.571400
# Epoch 84, CIFAR-10 Batch 3:  Loss = 0.8468, Validation Accuracy = 0.582400
# Epoch 84, CIFAR-10 Batch 4:  Loss = 0.8479, Validation Accuracy = 0.576800
# Epoch 84, CIFAR-10 Batch 5:  Loss = 0.8266, Validation Accuracy = 0.578400
# Epoch 85, CIFAR-10 Batch 1:  Loss = 0.8404, Validation Accuracy = 0.579600
# Epoch 85, CIFAR-10 Batch 2:  Loss = 0.9287, Validation Accuracy = 0.558200
# Epoch 85, CIFAR-10 Batch 3:  Loss = 0.9273, Validation Accuracy = 0.561400
# Epoch 85, CIFAR-10 Batch 4:  Loss = 0.7949, Validation Accuracy = 0.588400
# Epoch 85, CIFAR-10 Batch 5:  Loss = 0.7945, Validation Accuracy = 0.584200
# Epoch 86, CIFAR-10 Batch 1:  Loss = 0.7992, Validation Accuracy = 0.592000
# Epoch 86, CIFAR-10 Batch 2:  Loss = 0.8980, Validation Accuracy = 0.556200
# Epoch 86, CIFAR-10 Batch 3:  Loss = 0.8388, Validation Accuracy = 0.589800
# Epoch 86, CIFAR-10 Batch 4:  Loss = 0.8107, Validation Accuracy = 0.585400
# Epoch 86, CIFAR-10 Batch 5:  Loss = 0.7970, Validation Accuracy = 0.581400
# Epoch 87, CIFAR-10 Batch 1:  Loss = 0.8240, Validation Accuracy = 0.584200
# Epoch 87, CIFAR-10 Batch 2:  Loss = 0.8651, Validation Accuracy = 0.565600
# Epoch 87, CIFAR-10 Batch 3:  Loss = 0.8280, Validation Accuracy = 0.581800
# Epoch 87, CIFAR-10 Batch 4:  Loss = 0.7713, Validation Accuracy = 0.598400
# Epoch 87, CIFAR-10 Batch 5:  Loss = 0.7950, Validation Accuracy = 0.579000
# Epoch 88, CIFAR-10 Batch 1:  Loss = 0.7954, Validation Accuracy = 0.592000
# Epoch 88, CIFAR-10 Batch 2:  Loss = 0.8616, Validation Accuracy = 0.562000
# Epoch 88, CIFAR-10 Batch 3:  Loss = 0.8900, Validation Accuracy = 0.568800
# Epoch 88, CIFAR-10 Batch 4:  Loss = 0.7734, Validation Accuracy = 0.597000
# Epoch 88, CIFAR-10 Batch 5:  Loss = 0.7690, Validation Accuracy = 0.583800
# Epoch 89, CIFAR-10 Batch 1:  Loss = 0.8003, Validation Accuracy = 0.592600
# Epoch 89, CIFAR-10 Batch 2:  Loss = 0.8265, Validation Accuracy = 0.587600
# Epoch 89, CIFAR-10 Batch 3:  Loss = 0.8401, Validation Accuracy = 0.580600
# Epoch 89, CIFAR-10 Batch 4:  Loss = 0.7554, Validation Accuracy = 0.598200
# Epoch 89, CIFAR-10 Batch 5:  Loss = 0.7584, Validation Accuracy = 0.582600
# Epoch 90, CIFAR-10 Batch 1:  Loss = 0.7656, Validation Accuracy = 0.593200
# Epoch 90, CIFAR-10 Batch 2:  Loss = 0.8263, Validation Accuracy = 0.586000
# Epoch 90, CIFAR-10 Batch 3:  Loss = 0.8299, Validation Accuracy = 0.580000
# Epoch 90, CIFAR-10 Batch 4:  Loss = 0.7569, Validation Accuracy = 0.597800
# Epoch 90, CIFAR-10 Batch 5:  Loss = 0.7555, Validation Accuracy = 0.583200
# Epoch 91, CIFAR-10 Batch 1:  Loss = 0.7758, Validation Accuracy = 0.592600
# Epoch 91, CIFAR-10 Batch 2:  Loss = 0.8450, Validation Accuracy = 0.580800
# Epoch 91, CIFAR-10 Batch 3:  Loss = 0.8257, Validation Accuracy = 0.581400
# Epoch 91, CIFAR-10 Batch 4:  Loss = 0.7618, Validation Accuracy = 0.597200
# Epoch 91, CIFAR-10 Batch 5:  Loss = 0.7514, Validation Accuracy = 0.580200
# Epoch 92, CIFAR-10 Batch 1:  Loss = 0.7525, Validation Accuracy = 0.596000
# Epoch 92, CIFAR-10 Batch 2:  Loss = 0.8054, Validation Accuracy = 0.586800
# Epoch 92, CIFAR-10 Batch 3:  Loss = 0.8357, Validation Accuracy = 0.577600
# Epoch 92, CIFAR-10 Batch 4:  Loss = 0.7639, Validation Accuracy = 0.600600
# Epoch 92, CIFAR-10 Batch 5:  Loss = 0.7533, Validation Accuracy = 0.583600
# Epoch 93, CIFAR-10 Batch 1:  Loss = 0.7698, Validation Accuracy = 0.593800
# Epoch 93, CIFAR-10 Batch 2:  Loss = 0.8589, Validation Accuracy = 0.577600
# Epoch 93, CIFAR-10 Batch 3:  Loss = 0.8705, Validation Accuracy = 0.568200
# Epoch 93, CIFAR-10 Batch 4:  Loss = 0.8213, Validation Accuracy = 0.571200
# Epoch 93, CIFAR-10 Batch 5:  Loss = 0.7599, Validation Accuracy = 0.596600
# Epoch 94, CIFAR-10 Batch 1:  Loss = 0.7673, Validation Accuracy = 0.590200
# Epoch 94, CIFAR-10 Batch 2:  Loss = 0.8533, Validation Accuracy = 0.573000
# Epoch 94, CIFAR-10 Batch 3:  Loss = 0.8263, Validation Accuracy = 0.579800
# Epoch 94, CIFAR-10 Batch 4:  Loss = 0.7838, Validation Accuracy = 0.576000
# Epoch 94, CIFAR-10 Batch 5:  Loss = 0.7266, Validation Accuracy = 0.595400
# Epoch 95, CIFAR-10 Batch 1:  Loss = 0.7716, Validation Accuracy = 0.589600
# Epoch 95, CIFAR-10 Batch 2:  Loss = 0.8657, Validation Accuracy = 0.568800
# Epoch 95, CIFAR-10 Batch 3:  Loss = 0.8155, Validation Accuracy = 0.584000
# Epoch 95, CIFAR-10 Batch 4:  Loss = 0.7557, Validation Accuracy = 0.581600
# Epoch 95, CIFAR-10 Batch 5:  Loss = 0.7217, Validation Accuracy = 0.588200
# Epoch 96, CIFAR-10 Batch 1:  Loss = 0.7678, Validation Accuracy = 0.591200
# Epoch 96, CIFAR-10 Batch 2:  Loss = 0.8276, Validation Accuracy = 0.589000
# Epoch 96, CIFAR-10 Batch 3:  Loss = 0.8279, Validation Accuracy = 0.575200
# Epoch 96, CIFAR-10 Batch 4:  Loss = 0.8146, Validation Accuracy = 0.565400
# Epoch 96, CIFAR-10 Batch 5:  Loss = 0.7524, Validation Accuracy = 0.583400
# Epoch 97, CIFAR-10 Batch 1:  Loss = 0.8109, Validation Accuracy = 0.587000
# Epoch 97, CIFAR-10 Batch 2:  Loss = 0.8476, Validation Accuracy = 0.581800
# Epoch 97, CIFAR-10 Batch 3:  Loss = 0.8012, Validation Accuracy = 0.588200
# Epoch 97, CIFAR-10 Batch 4:  Loss = 0.7906, Validation Accuracy = 0.573400
# Epoch 97, CIFAR-10 Batch 5:  Loss = 0.8052, Validation Accuracy = 0.575800
# Epoch 98, CIFAR-10 Batch 1:  Loss = 0.7653, Validation Accuracy = 0.587200
# Epoch 98, CIFAR-10 Batch 2:  Loss = 0.8184, Validation Accuracy = 0.589600
# Epoch 98, CIFAR-10 Batch 3:  Loss = 0.7931, Validation Accuracy = 0.586400
# Epoch 98, CIFAR-10 Batch 4:  Loss = 0.7498, Validation Accuracy = 0.584000
# Epoch 98, CIFAR-10 Batch 5:  Loss = 0.7672, Validation Accuracy = 0.576800
# Epoch 99, CIFAR-10 Batch 1:  Loss = 0.7494, Validation Accuracy = 0.588800
# Epoch 99, CIFAR-10 Batch 2:  Loss = 0.8068, Validation Accuracy = 0.590600
# Epoch 99, CIFAR-10 Batch 3:  Loss = 0.7767, Validation Accuracy = 0.594400
# Epoch 99, CIFAR-10 Batch 4:  Loss = 0.7255, Validation Accuracy = 0.595600
# Epoch 99, CIFAR-10 Batch 5:  Loss = 0.7569, Validation Accuracy = 0.581400
# Epoch 100, CIFAR-10 Batch 1:  Loss = 0.7644, Validation Accuracy = 0.584000
# Epoch 100, CIFAR-10 Batch 2:  Loss = 0.8712, Validation Accuracy = 0.568800
# Epoch 100, CIFAR-10 Batch 3:  Loss = 0.8102, Validation Accuracy = 0.574600
# Epoch 100, CIFAR-10 Batch 4:  Loss = 0.7281, Validation Accuracy = 0.597000
# Epoch 100, CIFAR-10 Batch 5:  Loss = 0.7186, Validation Accuracy = 0.590400

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.5960558772087097

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
